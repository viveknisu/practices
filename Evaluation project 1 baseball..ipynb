# %% [markdown]
# # Baseball Case Study

# %% [raw]
# task is related to redict the number of wins for the given team .
#
# # input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, and Errors
#
# #output feature: Number of predicted wins (W)

# %% [markdown]
# # Importing the main libraries

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [raw]
# #loading the dataset

# %%
df=pd.read_csv('baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
#checkin the shape
df.shape
# Out:
# (30, 17)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [raw]
# # checking the null values

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [raw]
# # from this we cnclued that there is no any null value present

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
#statical summary
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [raw]
# # from above we see diff between the mean and std is heigh so skewness is present here.

# %%
sns.heatmap(df.isnull())
plt.title('null_values')
plt.show()

# %% [markdown]
# #from above  cleary see that there no any missiing or null values re present in given data set

# %% [raw]
# #Checking the correlation

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(),annot =True)

# %% [markdown]
# #Correlation of all the columns with our target variable

# %%
corr_matrix=df.corr()
corr_matrix['W'].sort_values(ascending=False)
# Out:
# W      1.000000
# SV     0.666530
# BB     0.484342
# SHO    0.471805
# R      0.430751
# 2B     0.427797
# HR     0.307407
# SO     0.111850
# CG     0.080533
# H      0.037612
# AB    -0.087947
# E     -0.089485
# SB    -0.157234
# 3B    -0.251118
# ER    -0.809435
# RA    -0.812952
# ERA   -0.819600
# Name: W, dtype: float64

# %%
pp=sns.pairplot(df)

# %%
#checking the out lairs
collist=df.columns.values
ncol=30
nrow=15
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(df[collist[i]],color='blue',orient='v')
    plt.tight_layout()

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.36540860e+00, 6.19077968e-01, 8.47731264e-01, 1.66368512e+00,
#         1.42017307e+00, 1.04119304e+00, 7.87298598e-01, 1.53490242e+00,
#         2.69762957e+00, 9.13883291e-01, 6.66233927e-01, 5.05110079e-01,
#         5.06955186e-01, 5.39806195e-01, 8.14628593e-01, 1.67160651e+00,
#         4.61469635e-01],
#        [1.97838300e-01, 1.34431656e-01, 7.11093535e-01, 9.70680764e-01,
#         1.27403389e-01, 1.23580856e+00, 2.43966683e-01, 5.36591904e-01,
#         1.54878442e-01, 6.01825582e-01, 1.65970766e-01, 2.48929848e-01,
#         2.54597523e-01, 5.39806195e-01, 1.72800005e-01, 2.49879323e-01,
#         6.07196888e-01],
#        [3.24325082e-03, 3.32905860e-01, 1.11523330e+00, 1.51891367e-01,
#         1.58879521e+00, 2.23807850e-01, 7.23377196e-01, 1.13914361e+00,
#         8.93981893e-01, 1.11449182e-01, 6.80339091e-01, 7.51623132e-01,
#         6.41346840e-01, 2.77264091e+00, 3.20914294e-01, 6.54856158e-01,
#         1.11724227e+00],
# ...

# %%
threeshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
x=df_new.drop('W',axis=1)
y=df_new['W']

# %%
y.shape
y=y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (29, 1)

# %%
x.shape
# Out:
# (29, 16)

# %% [raw]
# #checking skewness in x

# %%
x.skew()
# Out:
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# #removing the skewness

# %%
from sklearn.preprocessing import power_transform
input=power_transform(x)
traindata=pd.DataFrame(input,columns=x.columns)
traindata
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2995: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
#            R   AB    H        2B        3B        HR        BB        SO  \
# 0   0.962544  0.0  0.0  1.685188  1.006150 -0.741927 -1.605198 -2.550612
# 1   0.298863  0.0  0.0  0.138198  1.185227 -0.109958 -0.462096  0.093683
# 2  -0.312105  0.0  0.0  1.907385 -0.228819 -0.664354  1.232098 -0.935611
# 3  -1.308298  0.0  0.0 -0.837665 -0.432228 -0.860039 -1.162721 -0.230683
# 4   0.137737  0.0  0.0  0.911435  1.622636 -0.289647 -0.155686  0.044143
# 5   1.964209  0.0  0.0 -0.163010 -1.295827  1.631637  1.579494 -0.269583
# 6   0.698146  0.0  0.0 -1.542635 -1.182758  1.767734 -0.877217  0.770980
# 7  -0.852595  0.0  0.0  0.199897  0.068703  0.269125 -0.520476  0.556008
# 8   1.555951  0.0  0.0  1.255256  0.166017  0.065014  0.270944 -1.019210
# ...

# %%
traindata.skew()
# Out:
# R     -0.024842
# AB     0.000000
# H      0.000000
# 2B    -0.052793
# 3B    -0.075139
# HR     0.000448
# BB    -0.008572
# SO     0.051530
# SB    -0.009570
# RA    -0.011974
# ER    -0.004988
# ERA   -0.000401
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %% [raw]
# # from above we see there is no much skewness present in our independent datas

# %% [markdown]
# #selecting  the best random state

# %%
x=traindata
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
MaxR2=0
maxRs=0
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.10,random_state=i)
    Lr=LinearRegression()
    Lr.fit(x_train,y_train)
    predtest=Lr.predict(x_test)
    r2score=r2_score(y_test, predtest)
    if r2score>MaxR2:
        MaxR2=r2score
        maxRs=i
print('Best r2 score is',MaxR2,'on random state',maxRs)
# Out:
# Best r2 score is 0.9875098226314779 on random state 46

# %%
 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.10,random_state=46)

# %%
predtest=Lr.predict(x_test)
print(r2_score(y_test,predtest))
# Out:
# 0.982752040833319

# %%
#cross validation of the model
train_accuracy=r2_score(y_train,Lr.predict(x_train))
test_accuracy=r2_score(y_test,predtest)
from sklearn.model_selection import cross_val_score
for j in range (2,10):
    cv_score=cross_val_score(Lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print('at cross fold',{j},'cv_score is ',{cv_mean},'Accuracy score of training is ',{train_accuracy},'Accuracy score of testing is',{test_accuracy})
print("\n")
# Out:
# at cross fold {2} cv_score is  {-53.43812757804193} Accuracy score of training is  {0.9398797851733921} Accuracy score of testing is {0.982752040833319}
# at cross fold {3} cv_score is  {-0.11518180458521847} Accuracy score of training is  {0.9398797851733921} Accuracy score of testing is {0.982752040833319}
# at cross fold {4} cv_score is  {0.15396084746037883} Accuracy score of training is  {0.9398797851733921} Accuracy score of testing is {0.982752040833319}
# at cross fold {5} cv_score is  {0.3761324121236943} Accuracy score of training is  {0.9398797851733921} Accuracy score of testing is {0.982752040833319}
# at cross fold {6} cv_score is  {0.19600653614945682} Accuracy score of training is  {0.9398797851733921} Accuracy score of testing is {0.982752040833319}
# at cross fold {7} cv_score is  {0.21664994066765325} Accuracy score of training is  {0.9398797851733921} Accuracy score of testing is {0.982752040833319}
# ...

# %% [markdown]
# at cv score 5 out model is doing good so we select cv value =5

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=100,random_state=21)
rf.fit(x_train,y_train)
predf=rf.predict(x_test)
print(r2_score(y_test,predf))
# Out:
# 0.7821000000000001

# %%
from sklearn.model_selection import cross_val_score
cvs=cross_val_score(rf,x,y,cv=5)
print('cross validation score for RandomForestRegressor is',cvs.mean())
# Out:
# cross validation score for RandomForestRegressor is -0.578557202384375

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.1, 'random_state': 0}

# %%
ls=Lasso(alpha=0.1,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test) 

lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.9819031097348928

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.47376134919180324

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
#hyperparameter tunning
from sklearn.model_selection import GridSearchCV
parameters={'n_estimators':(10,30,50,70,90,100)
            , 'criterion':('mse','mae')
           ,'max_depth':(3,57,9,10)
           ,'max_features':('auto','sqrt','log2')
           ,'min_samples_split':(2,4,6)
           #,'min_weight_fraction_leaf':(0.0,0.1,0.2,0.3)
           }

# %%
GCV=GridSearchCV( RandomForestRegressor(),parameters,cv=5)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'criterion': ('mse', 'mae'),
#                          'max_depth': (3, 57, 9, 10),
#                          'max_features': ('auto', 'sqrt', 'log2'),
#                          'min_samples_split': (2, 4, 6),
#                          'n_estimators': (10, 30, 50, 70, 90, 100)})

# %%
GCV.best_params_#(best parameters found by GreadserchCV)
# Out:
# {'criterion': 'mse',
#  'max_depth': 3,
#  'max_features': 'sqrt',
#  'min_samples_split': 2,
#  'n_estimators': 10}

# %%
GCV_pred=GCV.best_estimator_.predict(x_test)

# %%
r2_score(y_test,GCV_pred)
# Out:
# 0.8022478819977806

# %%
import joblib
joblib.dump(GCV," baseball.pkl")
# Out:
# [' baseball.pkl']
