# %% [markdown]
# # Temperature Forecast

# %% [markdown]
# #task is  related  to forecast (next-day maximum and minimum air temperatures )with the held of the given data set

# %%
#importing the required Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#loading the data set
df=pd.read_csv('Evaluation Project - 10(Temperature Forecast Project using ML)')
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
#checking data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
# ...

# %%
#checking the null values
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
#columns
df.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
#plotting the heatmap 
sns.heatmap(df.isnull())

# %%
#lets handle the null values

# %%
#handlimg the null values of ['Date'] of the object type column
df['Date'].fillna('unkown',inplace=True)

# %%
df['Present_Tmax'].fillna(df['Present_Tmax'].mean(),inplace=True)

# %%
#handling the null values other remaing columns which are not object type with the help of for loopnc=
nc=['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
       'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
       'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
       'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
       'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin']
for i in nc:
    df[i].fillna(df[i].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
# plotting the heatmap
sns.heatmap(df.isnull())

# %%
#visualization
for i in df.columns:
    print(df[i].value_counts())
# Out:
# 13.0    312
# 12.0    310
# 2.0     310
# 3.0     310
# 4.0     310
# 5.0     310
# 6.0     310
# 7.0     310
# 8.0     310
# 9.0     310
# 10.0    310
# 11.0    310
# 25.0    310
# 23.0    310
# 14.0    310
# 15.0    310
# 16.0    310
# 18.0    310
# 20.0    310
# 22.0    310
# 24.0    310
# 17.0    310
# 19.0    310
# 21.0    310
# 1.0     310
# Name: station, dtype: int64
# 03-08-2015    25
# 20-08-2015    25
# 13-08-2015    25
# 04-08-2013    25
# 26-07-2016    25
#               ..
# 03-08-2013    25
# 15-08-2014    25
# 26-08-2014    25
# 15-08-2017    25
# unkown         2
# Name: Date, Length: 311, dtype: int64
# 31.4    112
# 29.4    111
# 29.1    108
# 29.7    107
# 30.6    105
#        ...
# 20.1      1
# 36.4      1
# 20.4      1
# 36.9      1
# 37.1      1
# Name: Present_Tmax, Length: 168, dtype: int64
# 24.0    161
# 23.8    153
# 23.1    144
# 23.5    143
# 23.3    142
#        ...
# 15.0      1
# 14.1      1
# 14.2      1
# 29.6      1
# 13.6      1
# ...

# %%
nc=['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
       'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
       'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
       'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
       'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin']
for i in nc:
    plt.show()
    sns.distplot(df[i])

# %%
#checking the correlation
df.corr()
# Out:
#                    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# station           1.000000      0.112655      0.131646    -0.066733
# Present_Tmax      0.112655      1.000000      0.618760    -0.204571
# Present_Tmin      0.131646      0.618760      1.000000     0.123143
# LDAPS_RHmin      -0.066733     -0.204571      0.123143     1.000000
# LDAPS_RHmax      -0.166984     -0.301787     -0.015140     0.579141
# LDAPS_Tmax_lapse  0.069107      0.570129      0.464151    -0.564580
# LDAPS_Tmin_lapse  0.104758      0.623496      0.762993     0.089476
# LDAPS_WS          0.005277     -0.121820     -0.034675     0.294361
# LDAPS_LH         -0.133357      0.135463     -0.009258    -0.070858
# LDAPS_CC1         0.006919     -0.311805      0.084447     0.613818
# LDAPS_CC2         0.003396     -0.213791      0.090263     0.745443
# LDAPS_CC3         0.000694     -0.144018     -0.002772     0.689679
# LDAPS_CC4         0.006126     -0.140729     -0.044335     0.514075
# ...

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(),annot=True)

# %%
#checking  the correlation matricxs with respect to our target variable
t=['Next_Tmax', 'Next_Tmin']
for i in t:
    corr_matrix=df.corr()
    print( corr_matrix[i].sort_values(ascending=False))
# Out:
# Next_Tmax           1.000000
# LDAPS_Tmax_lapse    0.827189
# Next_Tmin           0.621427
# Present_Tmax        0.610348
# LDAPS_Tmin_lapse    0.586983
# Present_Tmin        0.471806
# LDAPS_LH            0.157616
# station             0.107983
# Solar radiation     0.008795
# lon                 0.003052
# lat                -0.053510
# Slope              -0.102725
# LDAPS_PPT1         -0.118817
# DEM                -0.172538
# LDAPS_PPT2         -0.178383
# LDAPS_PPT4         -0.178718
# LDAPS_PPT3         -0.194143
# LDAPS_RHmax        -0.283738
# LDAPS_WS           -0.342729
# LDAPS_RHmin        -0.437898
# LDAPS_CC4          -0.446319
# LDAPS_CC1          -0.452541
# LDAPS_CC2          -0.490756
# LDAPS_CC3          -0.514680
# Name: Next_Tmax, dtype: float64
# Next_Tmin           1.000000
# LDAPS_Tmin_lapse    0.880176
# Present_Tmin        0.796670
# Present_Tmax        0.622741
# Next_Tmax           0.621427
# LDAPS_Tmax_lapse    0.586868
# station             0.128293
# ...

# %% [markdown]
# we can clearly see the correlation of all the columns with respect to our both target variables ['Next_Tmax', 'Next_Tmin']

# %%
#checking the statical summary
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7752.000000   7752.000000   7752.000000  7752.000000  7752.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.210637      2.956557      2.403036    14.596973     7.157124
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    46.046162    84.316923
# 50%      13.000000     29.900000     23.400000    55.313244    89.699505
# 75%      19.000000     32.000000     24.900000    67.038254    93.704500
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7752.000000       7752.000000  7752.000000  7752.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.932898          2.333973     2.173245    33.567001
# ...

# %%
#checking the outlairs
df.iloc[:,0:12].boxplot(figsize=[20,6])
plt.subplots_adjust(bottom=0.30)
plt.show()

# %%
df.iloc[:,12:24].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.20)
plt.show()

# %%
plt.boxplot(df[ 'Next_Tmin'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a211a7aaf0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a211a6f1f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a211a7a790>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a211a6f8b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a211a6fbb0>],
#  'means': []}

# %% [raw]
# #we can clearly see that outlairs are present

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Date']=le.fit_transform(df['Date'])
df['Date']
# Out:
# 0       290
# 1       290
# 2       290
# 3       290
# 4       290
#        ...
# 7747    304
# 7748    304
# 7749    304
# 7750    310
# 7751    310
# Name: Date, Length: 7752, dtype: int32

# %%
df
# Out:
#       station  Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0   290          28.7          21.4    58.255688    91.116364
# 1         2.0   290          31.9          21.6    52.263397    90.604721
# 2         3.0   290          31.6          23.3    48.690479    83.973587
# 3         4.0   290          32.0          23.4    58.239788    96.483688
# 4         5.0   290          31.4          21.9    56.174095    90.155128
# ...       ...   ...           ...           ...          ...          ...
# 7747     23.0   304          23.3          17.1    26.741310    78.869858
# 7748     24.0   304          23.3          17.7    24.040634    77.294975
# 7749     25.0   304          23.2          17.4    22.933014    77.243744
# 7750     13.0   310          20.0          11.3    19.794666    58.936283
# 7751     13.0   310          37.6          29.9    98.524734   100.000153
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  ...  \
# ...

# %% [markdown]
# #lets handel the outlairs
# from scipy.stats import zscore
# z=np.abs(zscore(df))
# z

# %% [markdown]
# threeshold=3
# print(np.where(z>3))

# %% [markdown]
# z[25][8]

# %% [markdown]
# ndf=df[(z<3).all(axis=1)]
# ndf

# %% [markdown]
# #checking the percentage data loss
# print(df.shape)
# print(ndf.shape)

# %% [markdown]
# #data losspercent
# losspercent=(7752-6894)/7752*100
# losspercent

# %% [markdown]
# #here we can clearly data loss prcent is too heigh so lets handle data set without removing ghe outlairs

# %%
#seprating the fature and target datas
x=df.iloc[:,0:23]
x.head()
# Out:
#    station  Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0   290          28.7          21.4    58.255688    91.116364
# 1      2.0   290          31.9          21.6    52.263397    90.604721
# 2      3.0   290          31.6          23.3    48.690479    83.973587
# 3      4.0   290          32.0          23.4    58.239788    96.483688
# 4      5.0   290          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_CC4  \
# 0         28.074101         23.006936  6.818887   69.451805  ...   0.130928
# 1         29.850689         24.035009  5.691890   51.937448  ...   0.127727
# 2         30.091292         24.565633  6.138224   20.573050  ...   0.142125
# 3         29.704629         23.326177  5.650050   65.727144  ...   0.134249
# 4         29.113934         23.486480  5.735004  107.965535  ...   0.170021
#
#    LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# ...

# %%
y1=df['Next_Tmax']
y2=df['Next_Tmin']

# %%
y1.head()
# Out:
# 0    29.1
# 1    30.5
# 2    31.1
# 3    31.7
# 4    31.2
# Name: Next_Tmax, dtype: float64

# %%
y2.head()
# Out:
# 0    21.2
# 1    22.5
# 2    23.9
# 3    24.3
# 4    22.5
# Name: Next_Tmin, dtype: float64

# %% [markdown]
# #here we can clearly see the our target columns re continious type so we will use Regresion model

# %%
#cheking the skewness
x.skew()
# Out:
# station             0.000000
# Date                0.000008
# Present_Tmax       -0.264137
# Present_Tmin       -0.367538
# LDAPS_RHmin         0.300220
# LDAPS_RHmax        -0.855015
# LDAPS_Tmax_lapse   -0.227880
# LDAPS_Tmin_lapse   -0.581763
# LDAPS_WS            1.579236
# LDAPS_LH            0.673757
# LDAPS_CC1           0.459458
# LDAPS_CC2           0.472350
# LDAPS_CC3           0.640735
# LDAPS_CC4           0.666482
# LDAPS_PPT1          5.393821
# LDAPS_PPT2          5.775355
# LDAPS_PPT3          6.457129
# LDAPS_PPT4          6.825464
# lat                 0.087062
# lon                -0.285213
# DEM                 1.723257
# Slope               1.563020
# Solar radiation    -0.511210
# dtype: float64

# %%
x.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation'],
#       dtype='object')

# %%
for i in x.columns:
    plt.figure()
    sns.distplot(x[i])
# Out:
# <ipython-input-30-c4db82183aec>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-30-c4db82183aec>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-30-c4db82183aec>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %%
#now we will handle the skewness of our faeture data
from sklearn.preprocessing import power_transform
input=power_transform(x)
fd=pd.DataFrame(input,columns=x.columns)
fd
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2995: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2960: RuntimeWarning: overflow encountered in power
#   out[pos] = (np.power(x[pos] + 1, lmbda) - 1) / lmbda
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:195: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:199: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims)
#        station      Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0    -1.860356  1.388061     -0.408897     -0.797707     0.172680
# 1    -1.648385  1.388061      0.705123     -0.720130    -0.241770
# 2    -1.454848  1.388061      0.595692     -0.027674    -0.501459
# ...

# %%
fd.skew()
# Out:
# station            -0.204565
# Date               -0.282795
# Present_Tmax       -0.035006
# Present_Tmin       -0.012048
# LDAPS_RHmin        -0.017469
# LDAPS_RHmax        -0.115143
# LDAPS_Tmax_lapse   -0.009351
# LDAPS_Tmin_lapse   -0.017827
# LDAPS_WS            0.002408
# LDAPS_LH            0.057403
# LDAPS_CC1           0.046757
# LDAPS_CC2           0.045326
# LDAPS_CC3           0.087933
# LDAPS_CC4           0.126895
# LDAPS_PPT1          1.404189
# LDAPS_PPT2          1.577808
# LDAPS_PPT3          1.747820
# LDAPS_PPT4          1.963848
# lat                 0.000000
# lon                -0.198429
# DEM                 0.039456
# Slope               0.233968
# Solar radiation    -0.176636
# dtype: float64

# %%
for i in fd.columns:
    plt.figure()
    sns.distplot(fd[i])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# <ipython-input-33-83ffc57a1f80>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <ipython-input-33-83ffc57a1f80>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# ...

# %%
#scaling of the data
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(fd)
x=pd.DataFrame(x,columns=fd.columns)
x.head()
# Out:
#     station      Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0 -1.860356  1.388061     -0.408897     -0.797707     0.172680     0.272915
# 1 -1.648385  1.388061      0.705123     -0.720130    -0.241770     0.185831
# 2 -1.454848  1.388061      0.595692     -0.027674    -0.501459    -0.773454
# 3 -1.273958  1.388061      0.741829      0.014910     0.171612     1.316777
# 4 -1.102545  1.388061      0.523313     -0.602237     0.031496     0.110968
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  ...  LDAPS_CC4  \
# 0         -0.556645         -0.312411  0.093387  0.310382  ...  -0.584801
# 1          0.043756          0.144368 -0.625565 -0.211695  ...  -0.603593
# 2          0.127214          0.394571 -0.314874 -1.375126  ...  -0.520112
# 3         -0.006660         -0.174463 -0.656732  0.204179  ...  -0.565449
# 4         -0.208627         -0.103881 -0.593836  1.300503  ...  -0.365736
#
# ...

# %%
x.shape
# Out:
# (7752, 23)

# %%
y1.shape
# Out:
# (7752,)

# %%
y1=y1.values.reshape(-1,1)

# %%
y1.shape
# Out:
# (7752, 1)

# %%
y2=y2.values.reshape(-1,1)

# %%
y2.shape
# Out:
# (7752, 1)

# %% [markdown]
# #loading the required models
# #here our tagest variable is continious in nature so we will use Linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # y1=df['Next_Tmax'](ist target variable)

# %%
#selecting the best random state
MaxR2=0
maxRs=0
for i in range (0,500):
    x_train,x_test,y1_train,y1_test=train_test_split(x,y1,test_size=0.05,random_state=i)
    Lr=LinearRegression()
    Lr.fit(x_train,y1_train)
    pred=Lr.predict(x_test)
    r2score=r2_score(y1_test,pred)
    if r2score>MaxR2:
        MaxR2=r2score
        maxRs=i
        
print('best r2score is',MaxR2,'at random_stae', maxRs)
# Out:
# best r2score is 0.8229387064031922 at random_stae 275

# %%
#best random state=453
x_train,x_test,y1_train,y1_test=train_test_split(x,y1,test_size=0.05,random_state=275)

# %%
print(mean_squared_error(y1_test,pred))
# Out:
# 16.97925442332941

# %%
print(mean_absolute_error(y1_test,pred))
# Out:
# 3.256541973010468

# %%
#crossvalidation
from sklearn.model_selection import cross_val_score
cvr=cross_val_score(Lr,x,y1,cv=5)
print ('crossvalidation of the LinearRegression is',cvr.mean())
# Out:
# crossvalidation of the LinearRegression is 0.6847878941837425

# %%
#crossvalidation
from sklearn.model_selection import cross_val_score
cvr=cross_val_score(rf,x,y1,cv=5)
print ('crossvalidation of the RandomForestRegressor is',cvr.mean())
# Out:
# crossvalidation of the RandomForestRegressor is 0.6848944695138506

# %% [markdown]
# # y2=df['Next_Tmin']

# %%
#selecting the best random state
MaxR2=0
maxRs=0
for i in range (0,500):
    x_train,x_test,y2_train,y2_test=train_test_split(x,y2,test_size=0.05,random_state=i)
    Lr=LinearRegression()
    Lr.fit(x_train,y2_train)
    pred=Lr.predict(x_test)
    r2score=r2_score(y2_test,pred)
    if r2score>MaxR2:
        MaxR2=r2score
        maxRs=i
        
print('best r2score is',MaxR2,'at random_stae', maxRs)
# Out:
# best r2score is 0.8699646668589707 at random_stae 29

# %%
#best random state=29
x_train,x_test,y2_train,y2_test=train_test_split(x,y2,test_size=0.05,random_state=29)

# %%
print(mean_squared_error(y2_test,pred))
print(mean_absolute_error(y2_test,pred))
# Out:
# 10.618431941190735
# 2.565457464360625

# %%
#crossvalidation
from sklearn.model_selection import cross_val_score
cvr=cross_val_score(Lr,x,y2,cv=5)
print ('crossvalidation of the LinearRegression is',cvr.mean())
# Out:
# crossvalidation of the LinearRegression is 0.7644165123351614

# %% [markdown]
# # parameters tunning

# %%
#ensemble method
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
parametrs={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parametrs)
clf.fit(x_train,y1_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'log2'}

# %% [markdown]
# # y1=df['Next_Tmax'](ist target variable)

# %%
rf=RandomForestRegressor(criterion='mae',max_features='log2')
rf.fit(x_train,y1_train)
pred=rf.predict(x_test)
rfs=r2_score(y1_test,pred)
print('r2_score',rfs*100)
# Out:
# r2_score -3.159576316772128

# %%
#cross validation
cvr=cross_val_score(rf,x,y1,cv=5)
print ('crossvalidation of the RandomforestRegression is',cvr.mean())
# Out:
# crossvalidation of the RandomforestRegression is 0.677054928950513

# %% [markdown]
# # y2='Next_Tmin'

# %%
rf=RandomForestRegressor(criterion='mae',max_features='log2')
rf.fit(x_train,y2_train)
pred=rf.predict(x_test)
rfs=r2_score(y2_test,pred)
print('r2_score',rfs*100)
# Out:
# r2_score 94.0896983651871

# %%
#cross validation
cvr=cross_val_score(rf,x,y2,cv=5)
print ('crossvalidation of the RandomforestRegression is',cvr.mean())
# Out:
# crossvalidation of the RandomforestRegression is 0.7593486561565256

# %% [raw]
# # where we can clerly see diff between r2score and cvscore is lower in case of linear Regression copare to RandomforestRegression so we consider LinearRegresion as best modet

# %%
import joblib
joblib.dump(Lr,'Temperature Forecast Project using ML')
# Out:
# ['Temperature Forecast Project using ML']
