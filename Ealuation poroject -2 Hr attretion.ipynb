# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('HR_attrition_rate.csv')
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Departments            14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
#checking the null values
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Departments              0
# salary                   0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %% [raw]
# # from above data set we clearly see that there is no null values present in our data set

# %%
#checking the columns
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Departments ', 'salary'],
#       dtype='object')

# %%
df['Work_accident']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 14994    0
# 14995    0
# 14996    0
# 14997    0
# 14998    0
# Name: Work_accident, Length: 14999, dtype: int64

# %%
df['promotion_last_5years']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 14994    0
# 14995    0
# 14996    0
# 14997    0
# 14998    0
# Name: promotion_last_5years, Length: 14999, dtype: int64

# %%
df.drop('Work_accident',axis=1,inplace=True)
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  left  promotion_last_5years Departments   salary
# 0                   3     1                      0        sales     low
# 1                   6     1                      0        sales  medium
# 2                   4     1                      0        sales  medium
# 3                   5     1                      0        sales     low
# 4                   3     1                      0        sales     low

# %%
df.drop('promotion_last_5years',axis=1,inplace=True)

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  left Departments   salary
# 0                   3     1        sales     low
# 1                   6     1        sales  medium
# 2                   4     1        sales  medium
# 3                   5     1        sales     low
# 4                   3     1        sales     low

# %%
#now we will transform the object data into float or integer form
from sklearn.preprocessing import LabelEncoder
Le=LabelEncoder()
Le.fit_transform(df['salary'])
# Out:
# array([1, 2, 2, ..., 1, 1, 1])

# %%
df['salary']=Le.fit_transform(df['salary'])
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  left Departments   salary
# 0                   3     1        sales       1
# 1                   6     1        sales       2
# 2                   4     1        sales       2
# 3                   5     1        sales       1
# 4                   3     1        sales       1

# %%
Le=LabelEncoder()
Le.fit_transform(df['Departments '])
# Out:
# array([7, 7, 7, ..., 8, 8, 8])

# %%
df['Departments ']=Le.fit_transform(df['Departments '])
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  left  Departments   salary
# 0                   3     1             7       1
# 1                   6     1             7       2
# 2                   4     1             7       2
# 3                   5     1             7       1
# 4                   3     1             7       1

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  left  Departments   salary
# 0                       157                   3     1             7       1
# 1                       262                   6     1             7       2
# ...

# %%
#checking again 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   satisfaction_level    14999 non-null  float64
#  1   last_evaluation       14999 non-null  float64
#  2   number_project        14999 non-null  int64
#  3   average_montly_hours  14999 non-null  int64
#  4   time_spend_company    14999 non-null  int64
#  5   left                  14999 non-null  int64
#  6   Departments           14999 non-null  int32
#  7   salary                14999 non-null  int32
# dtypes: float64(2), int32(2), int64(4)
# memory usage: 820.4 KB

# %% [markdown]
# #from above we conclued that there is no more catogorical datas are present in our data set

# %%
df.corr()
# Out:
#                       satisfaction_level  last_evaluation  number_project  \
# satisfaction_level              1.000000         0.105021       -0.142970
# last_evaluation                 0.105021         1.000000        0.349333
# number_project                 -0.142970         0.349333        1.000000
# average_montly_hours           -0.020048         0.339742        0.417211
# time_spend_company             -0.100866         0.131591        0.196786
# left                           -0.388375         0.006567        0.023787
# Departments                     0.003153         0.007772        0.009268
# salary                          0.011754         0.013965        0.009672
#
#                       average_montly_hours  time_spend_company      left  \
# satisfaction_level               -0.020048           -0.100866 -0.388375
# last_evaluation                   0.339742            0.131591  0.006567
# number_project                    0.417211            0.196786  0.023787
# ...

# %%
#checking correlation matrics
corr_matrix=df.corr()
corr_matrix['salary'].sort_values(ascending=False)
# Out:
# salary                  1.000000
# last_evaluation         0.013965
# satisfaction_level      0.011754
# number_project          0.009672
# average_montly_hours    0.007082
# Departments             0.000685
# left                   -0.001294
# time_spend_company     -0.003086
# Name: salary, dtype: float64

# %%
plt.figure(figsize=(15,20))
sns.heatmap(df.corr(),annot=True)

# %%
sns.pairplot(df,hue='salary')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
#checking out the statical summary
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company          left  Departments   \
# count          14999.000000        14999.000000  14999.000000  14999.000000
# mean             201.050337            3.498233      0.238083      5.870525
# std               49.943099            1.460136      0.425924      2.868786
# min               96.000000            2.000000      0.000000      0.000000
# ...

# %%
#checking the out lairs
#checking the out lairs
collist=df.columns.values
ncol=30
nrow=15
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(df[collist[i]],color='blue',orient='v')
    plt.tight_layout()

# %% [markdown]
# #from we can clearly see that there are no oulairs present in larger amount soo will not remove out lairs

# %%
#sepreating the features and target data
x=df.drop('salary',axis=1)
x.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  left  Departments
# 0                   3     1             7
# 1                   6     1             7
# 2                   4     1             7
# 3                   5     1             7
# 4                   3     1             7

# %%
y=df['salary']
y
# Out:
# 0        1
# 1        2
# 2        2
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: salary, Length: 14999, dtype: int32

# %%
#checking the skewness in our feature data
x.skew()
# Out:
# satisfaction_level     -0.476360
# last_evaluation        -0.026622
# number_project          0.337706
# average_montly_hours    0.052842
# time_spend_company      1.853319
# left                    1.230043
# Departments            -0.833084
# dtype: float64

# %%
#removing the skewness
from sklearn.preprocessing import power_transform
input=power_transform(x)
x=pd.DataFrame(power_transform(x),columns=x.columns)
x.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0           -0.988379        -1.087868       -1.613222             -0.868447
# 1            0.738408         0.841836        0.982098              1.198659
# 2           -1.786497         0.957688        2.222209              1.378939
# 3            0.361763         0.899777        0.982098              0.471632
# 4           -1.022139        -1.146921       -1.613222             -0.825293
#
#    time_spend_company      left  Departments
# 0           -0.143951  1.788917      0.328538
# 1            1.575753  1.788917      0.328538
# 2            0.662038  1.788917      0.328538
# 3            1.196143  1.788917      0.328538
# 4           -0.143951  1.788917      0.328538

# %%
x.shape
# Out:
# (14999, 7)

# %%
y.shape
y=y.values.reshape(-1,1)

# %%
y.shape
# Out:
# (14999, 1)

# %%
#scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit_transform(x)
x=sc.fit_transform(x)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
#selecting the best Random state
maxAccu=0
maxRS=0
for i in range (0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
    lr=LogisticRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc > maxAccu:
        maxAccu=acc
        maxRs=i
print ('best Accuracy Score is :',maxAccu, 'on random_state:',maxRS)
# Out:
# best Accuracy Score is : 0.518 on random_state: 0

# %%
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# [[  0 126 129]
#  [  0 937 525]
#  [  0 756 527]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       255
#            1       0.52      0.64      0.57      1462
#            2       0.45      0.41      0.43      1283
#
#     accuracy                           0.49      3000
#    macro avg       0.32      0.35      0.33      3000
# weighted avg       0.44      0.49      0.46      3000

# %%
from sklearn.tree import DecisionTreeClassifier 
dt=DecisionTreeClassifier ()
dt.fit(x_train,y_train)
pred=dt.predict(x_test)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.581
# [[ 96  87  72]
#  [108 917 437]
#  [ 90 463 730]]
#               precision    recall  f1-score   support
#
#            0       0.33      0.38      0.35       255
#            1       0.63      0.63      0.63      1462
#            2       0.59      0.57      0.58      1283
#
#     accuracy                           0.58      3000
#    macro avg       0.51      0.52      0.52      3000
# weighted avg       0.58      0.58      0.58      3000

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
pred=rf.predict(x_test)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.6126666666666667
# [[  75  102   78]
#  [  10 1010  442]
#  [   7  523  753]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.29      0.43       255
#            1       0.62      0.69      0.65      1462
#            2       0.59      0.59      0.59      1283
#
#     accuracy                           0.61      3000
#    macro avg       0.67      0.52      0.56      3000
# weighted avg       0.62      0.61      0.61      3000

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
pred=svc.predict(x_test)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.4826666666666667
# [[  0 131 124]
#  [  0 946 516]
#  [  0 781 502]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       255
#            1       0.51      0.65      0.57      1462
#            2       0.44      0.39      0.41      1283
#
#     accuracy                           0.48      3000
#    macro avg       0.32      0.35      0.33      3000
# weighted avg       0.44      0.48      0.45      3000

# %% [markdown]
# #here we are geting heighest accuracy with RandomForestClassifier i.e 61 percent

# %%
#checking crossvalidation score
from sklearn.model_selection import cross_val_score
cvs=cross_val_score(lr,x,y,cv=5)
print('cross validation score for logisticRegression is',cvs.mean())
# Out:
# cross validation score for logisticRegression is 0.48923538957430257

# %%
from sklearn.model_selection import cross_val_score
cvs=cross_val_score(dt,x,y,cv=5)
print('cross validation score for DecissionTreeClassifier is',cvs.mean())
# Out:
# cross validation score for DecissionTreeClassifier is 0.617597110147827

# %%
from sklearn.model_selection import cross_val_score
cvs=cross_val_score(rf,x,y,cv=5)
print('cross validation score for RandomforestClassifier is',cvs.mean())
# Out:
# cross validation score for RandomforestClassifier is 0.6343307102367455

# %%
from sklearn.model_selection import cross_val_score
cvs=cross_val_score(svc,x,y,cv=5)
print('cross validation score for Support Vector Classifier is',cvs.mean())
# Out:
# cross validation score for Support Vector Classifier is 0.48976927864843833

# %%
#hyperparameter tunning
from sklearn.model_selection import GridSearchCV
parameters={'n_estimators':(10,30,50,70,90,100)
            , 'criterion':('gini','entropy')
           ,'max_depth':(3,57,9,10)
           ,'max_features':('auto','sqrt')
           ,'min_samples_split':(2,4,6)
           #,'min_weight_fraction_leaf':(0.0,0.1,0.2,0.3)
           }

# %%
GCV=GridSearchCV( RandomForestClassifier(),parameters,cv=5)
GCV.fit(x_train,y_train)

# %%
GCV.best_params_#(best parameters found by GreadserchCV)

# %%
GCV_pred=GCV.best_estimator_.predict(x_test)

# %%
accuracy_score(y_test,GCV_pred)

# %%
import joblib
joblib.dump(GCV.best_estimator,"HR_attrition_rate.pkl")
